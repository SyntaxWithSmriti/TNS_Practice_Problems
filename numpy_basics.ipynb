# %%
import numpy as np

# %%
Marks = np.array([12,54,78,32,95,42])

# %%
# 2,3
# transpose
# mean

# %%
Marks = Marks.reshape(2,3)
print(Marks)
# Out:
# [[12 54 78]
#  [32 95 42]]

# %%
print(Marks.mean())
print(Marks)
# Out:
# 52.166666666666664
# [[12 54 78]
#  [32 95 42]]

# %%
Marks = Marks.T
print(Marks)
# Out:
# [[12 32]
#  [54 95]
#  [78 42]]

# %%
# condition score less than 40 and 80 greater

# %%
print(Marks[(Marks>40)&(Marks<80)])
# Out:
# [54 78 42]

# %%
Marks.size
Marks.dtype
Marks.shape
# Out:
# (3, 2)

# %%
print(np.ones([3,3]))
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]
#  [1. 1. 1.]]

# %%
grid = np.array([55,72,88,41,95,63,77,58,90])
grid = grid.reshape(3,3)

# %%
print(grid)
# Out:
# [[55 72 88]
#  [41 95 63]
#  [77 58 90]]

# %%
print(grid[1,2])
# Out:
# 63

# %%
print(grid[1,:])
# Out:
# [41 95 63]

# %%
print(grid[:,1])
# Out:
# [72 95 58]

# %%
print(grid.sum(axis=1))
# Out:
# [215 199 225]

# %%
print(np.round(grid.mean(axis=0),1))
# Out:
# [57.7 75.  80.3]

# %%
print(grid.max())
# Out:
# 95

# %%
marks = np.array([55,72,88,41,95,63])
names = np.array(["Aisha","Ben" ,"Carla" ,"Dev" ,"Eli" ,"Farah"])

# %%
print(names[marks>70])
# Out:
# ['Ben' 'Carla' 'Eli']

# %%
print(np.sum([(marks>40) & (marks<80)]))
# Out:
# 4

# %%
print(np.where(marks>80,"A","B"))
# Out:
# ['B' 'B' 'A' 'B' 'A' 'B']
