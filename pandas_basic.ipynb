# %%
import pandas as pd
import numpy as np

# %%
temps = pd.Series([18,22,31,27],index = ["Mon" , "Tue" , "Wed" , "Thu"])
print(f"The temperature of Wednesday is : {temps["Wed"]}")
print(f"The mean of all temperatures is : {temps.mean()}")
# Out:
# The temperature of Wednesday is : 31
# The mean of all temperatures is : 24.5
